# %% [markdown]
# <a href="https://colab.research.google.com/github/arvindhraja/oracle/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Terex')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(10, 50, size=len(categories))

plt.bar(categories, values, color='cyan')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('TEREX')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['A', 'B', 'C', 'D']
values1 = np.array([25, 40, 15, 20])
values2 = np.array([30, 20, 25, 25])

bar_width = 0.35

r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]

plt.figure(figsize=(10, 6))

plt.bar(r1, values1, width=bar_width, label='Data Series 1', color='skyblue')
plt.bar(r2, values2, width=bar_width, label='Data Series 2', color='lightcoral')

plt.xlabel('Categories', fontweight='bold')
plt.ylabel('Values', fontweight='bold')
plt.title('Bar Chart with Legend', fontweight='bold')

plt.xticks([r + bar_width / 2 for r in range(len(categories))], categories)

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('TEREX')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.DataFrame({'Values': np.random.randn(1000)})

plt.figure(figsize=(10, 6))
sns.histplot(df, x='Values', bins=30, kde=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('TEREX')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.DataFrame({'Values': np.random.randn(100)})

plt.figure(figsize=(10, 10))
sns.boxplot(data=df, y='Values', color='skyblue')
plt.ylabel('Value')
plt.title('TEREX')
# Out:
# Text(0.5, 1.0, 'TEREX')
